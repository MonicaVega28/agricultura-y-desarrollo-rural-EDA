# %% [markdown]
# Análisis exploratorio 'Agricultura y Desarrollo Local EDA en Antiquia'

# %%
import funciones_primeras_graficas as func
import plotly.express as px
import plotly.graph_objects as go

# %%
# Lectura de los datos desde diferentes origenes
df_hasta_2000 = func.leer_archivo("datos_antes_2000.csv")
display(len(df_hasta_2000))

df_desde_2000 = func.leer_TablaBD("produccion_agricola_antioquia")
display(len(df_desde_2000))

df_hasta_2000["Área Total"] = df_hasta_2000["Área Total"].str.replace(",", ".").astype(float)
df_hasta_2000["Área Producción"] = df_hasta_2000["Área Producción"].str.replace(",", ".").astype(float)
df_hasta_2000["Volumen Producción"] = df_hasta_2000["Volumen Producción"].str.replace(",", ".").astype(float)
# Out:
# 5564
# c:\Users\Camila\Documents\Especialización\Fundamentos de análica y ciencia de datos\agricultura-y-desarrollo-rural-EDA\ConexionBD.py:25: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"SELECT  * FROM dbo.{nombre_tabla}", conn)
# 28881

# %%
# Union de ambas fuentes de datos
df_completo = func.unir_data(df_hasta_2000, df_desde_2000)
display(len(df_completo))
# Out:
# 34445

# %%
df_completo_TipoDatos = func.conversion_Datos(df_completo, 'Área Total', 'float64')
df_completo_TipoDatos = func.conversion_Datos(df_completo, 'Área Producción', 'float64')
df_completo_TipoDatos = func.conversion_Datos(df_completo, 'Volumen Producción', 'float64')
df_completo_TipoDatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34445 entries, 0 to 34444
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tipo                34445 non-null  object
#  1   Rubro               34445 non-null  object
#  2   Subregion           34445 non-null  object
#  3   Año                 34445 non-null  int64
#  4   Municipio           34445 non-null  object
#  5   Área Total          34403 non-null  float64
#  6   Área Producción     34395 non-null  float64
#  7   Volumen Producción  34395 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 2.1+ MB

# %% [markdown]
# Primera pregunta

# %%
df_volumen_area = func.preparar_datos_area_volumen(df_completo)

# %%
#fig1 = func.grafica_top(df_volumen_area, columna_valor="Volumen Producción", titulo="Top 10 Volumen por Rubro Histórica")
fig = func.grafica_top(
    df_volumen_area,
    "Volumen Producción",
    "Rubros con mayor producción histórica",
    "Volumen de Producción acumulada en Antioquia"
)
fig.show()

# %%
#fig2 = func.grafica_top(df_volumen_area, columna_valor="Área Producción", titulo="Top 10 Productos por Área Histórica")
fig = func.grafica_top(
    df_volumen_area,
    "Área Producción",
    "Rubros con mayor área cultivada",
    "Volumen de Area acumulada en Antioquia"
)
fig.show()

# %%
'''
top_compare = df_volumen_area.sort_values(
    by="Produccion_norm",
    ascending=False
).head(10)

fig3 = px.bar(
    top_compare,
    x="Rubro",
    y=["Produccion_norm", "Area_norm"],
    barmode="group",
    title="Comparación Normalizada Producción vs Área (Escala 0-1)"
)
'''
fig3 = func.grafica_comparacion_normalizada(df_volumen_area)
fig3.show()

# %% [markdown]
# Segunda pregunta

# %%
fig2 = func.top_municipios(df_completo)
fig2.show()

# %%
#df_treemap = df_completo.groupby(["Subregion", "Municipio"])["Volumen Producción"].sum().reset_index()

# %%
fig = func.peso_produccion_sub_municipio(df_completo)
fig.show()

# %%
#fig3 = func.heatmap_especializacion(df_completo)
#fig3.show()

# %%
#fig4 = func.especializacion_subregion(df_completo)
#fig4.show()

# %%
fig = func.top_rubro_subregion(df_completo)
fig.show()
# Out:
# c:\Users\Camila\Documents\Especialización\Fundamentos de análica y ciencia de datos\agricultura-y-desarrollo-rural-EDA\funciones_primeras_graficas.py:345: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   labels = list(pd.unique(agg["Subregion"].tolist() + agg["Rubro"].tolist()))

# %% [markdown]
# Tercera pregunta

# %%
water = func.variacion_produccion(df_completo)
water.show()
